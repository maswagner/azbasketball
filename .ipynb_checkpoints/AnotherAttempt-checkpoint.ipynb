# %%
import pandas as pd

# %%
raw_games = pd.read_csv('HolyCollegeBasketball.csv')
raw_teamrec = pd.read_csv('PacRecords.csv')

# %%
raw_games.rename(columns = {'Team':'TEAM'}, inplace = True)
raw_games.head()
# Out:
#    YEAR     TEAM       DATE LOCATION             OPPONENT RESULT  TEAMSCORE  \
# 0  2018  Arizona  Fri 11-10        H     Northern Arizona      W        101
# 1  2018  Arizona  Sun 11-12        H                 UMBC      W        103
# 2  2018  Arizona  Thu 11-16        H  Cal St. Bakersfield      W         91
# 3  2018  Arizona  Wed 11-22        N   North Carolina St.      L         84
# 4  2018  Arizona  Thu 11-23        N                  SMU      L         60
#
#    OPPSCORE RECORD  WAB  ...   OPPP OEFG%  OTO%  OOR%  OFTR   DPPP  DEFG%  \
# 0        67    1-0  0.0  ...  139.8  64.0  15.2  52.2  56.1   92.8   43.1
# 1        78    2-0  0.1  ...  139.9  72.7  17.7  34.6  21.9  105.9   53.2
# 2        59    3-0  0.2  ...  125.5  64.3  17.9  30.4  73.5   81.3   40.2
# 3        90    3-1 -0.4  ...  114.9  48.4  10.9  38.5  56.5  123.1   56.4
# 4        66    3-2 -1.1  ...   90.9  52.1  30.3  36.7  40.4  100.0   37.1
#
#    DTO%  DOR%  DFTR
# 0  18.0  27.9  51.7
# 1  13.6  17.9  25.8
# ...

# %%
raw_teamrec.head()
# Out:
#    YEAR     TEAM  REC1YRAGOW  REC1YRAGOL  REC2YRAGOW  REC2YRAGOL  REC3YRAGOW  \
# 0  2018  Arizona          32           5          25           9          34
# 1  2019  Arizona          27           8          32           5          25
# 2  2020  Arizona          17          15          27           8          32
# 3  2021  Arizona          21          11          17          15          27
# 4  2022  Arizona          17           9          21          11          17
#
#    REC3YRAGOL  REC4YRAGOW  REC4YRAGOL  REC5YRAGOW  REC5YRAGOL
# 0           4          33           5          27           8
# 1           9          34           4          33           5
# 2           5          25           9          34           4
# 3           8          32           5          25           9
# 4          15          27           8          32           5

# %%
raw_teamrec['TEAMYEAR'] = raw_teamrec['TEAM'] + raw_teamrec['YEAR'].astype(str) 
teamrec = raw_teamrec.set_index('TEAMYEAR')

# %%
raw_games['TEAMYEAR'] = raw_games['TEAM'] + raw_games['YEAR'].astype(str)
games = raw_games.set_index('TEAMYEAR')
games.head()
# Out:
#              YEAR     TEAM       DATE LOCATION             OPPONENT RESULT  \
# TEAMYEAR
# Arizona2018  2018  Arizona  Fri 11-10        H     Northern Arizona      W
# Arizona2018  2018  Arizona  Sun 11-12        H                 UMBC      W
# Arizona2018  2018  Arizona  Thu 11-16        H  Cal St. Bakersfield      W
# Arizona2018  2018  Arizona  Wed 11-22        N   North Carolina St.      L
# Arizona2018  2018  Arizona  Thu 11-23        N                  SMU      L
#
#              TEAMSCORE  OPPSCORE RECORD  WAB  ...   OPPP OEFG%  OTO%  OOR%  \
# TEAMYEAR                                      ...
# Arizona2018        101        67    1-0  0.0  ...  139.8  64.0  15.2  52.2
# Arizona2018        103        78    2-0  0.1  ...  139.9  72.7  17.7  34.6
# Arizona2018         91        59    3-0  0.2  ...  125.5  64.3  17.9  30.4
# Arizona2018         84        90    3-1 -0.4  ...  114.9  48.4  10.9  38.5
# Arizona2018         60        66    3-2 -1.1  ...   90.9  52.1  30.3  36.7
#
# ...

# %%
rest = 'Arizona'
resy = 2018

def search(team, year):
    multgames = 
    
    return multgames

search(rest, resp)
# Out:
#              YEAR     TEAM       DATE LOCATION             OPPONENT RESULT  \
# TEAMYEAR
# Arizona2018  2018  Arizona  Fri 11-10        H     Northern Arizona      W
# Arizona2018  2018  Arizona  Sun 11-12        H                 UMBC      W
# Arizona2018  2018  Arizona  Thu 11-16        H  Cal St. Bakersfield      W
# Arizona2018  2018  Arizona  Wed 11-22        N   North Carolina St.      L
# Arizona2018  2018  Arizona  Thu 11-23        N                  SMU      L
# ...           ...      ...        ...      ...                  ...    ...
# Arizona2022  2022  Arizona   Fri 3-11        N             Colorado      W
# Arizona2022  2022  Arizona   Sat 3-12        N                 UCLA      W
# Arizona2022  2022  Arizona   Fri 3-18        N      Wright St. (16)      W
# Arizona2022  2022  Arizona   Sun 3-20        N              TCU (9)      W
# Arizona2022  2022  Arizona   Thu 3-24        N          Houston (5)      L
#
# ...
